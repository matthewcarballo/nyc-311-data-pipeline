# %%
import pandas as pd
import psycopg2

query = "select * from public.fct_311"

with psycopg2.connect(
    dbname="nyc_311",
    user="matthewcarballo",
    host="localhost",
    port=5432,
) as conn:
    df = pd.read_sql(query, conn)

print(f"{len(df):,} rows x {len(df.columns)} columns")
df.head()
